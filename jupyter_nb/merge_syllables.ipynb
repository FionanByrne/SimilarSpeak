# %%
import os
import cmudict
import collections
import itertools

# %%
a = [["0"], ["1"], ["2"], ["3"]]
b = [["a"], ["bc"], ["def"]]
c = [["x"]]
x = list(itertools.product(a, b, c))
x
# Out:
# [(['0'], ['a'], ['x']),
#  (['0'], ['bc'], ['x']),
#  (['0'], ['def'], ['x']),
#  (['1'], ['a'], ['x']),
#  (['1'], ['bc'], ['x']),
#  (['1'], ['def'], ['x']),
#  (['2'], ['a'], ['x']),
#  (['2'], ['bc'], ['x']),
#  (['2'], ['def'], ['x']),
#  (['3'], ['a'], ['x']),
#  (['3'], ['bc'], ['x']),
#  (['3'], ['def'], ['x'])]

# %%
y1 = [['S', 'AE'], ['CH', 'AH'], ['DH', 'AH'], ['F', 'AH'], ['G', 'AH'], ['JH', 'AH'], ['K', 
'AH'], ['L', 'AH'], ['M', 'AH'], ['N', 'AH'], ['P', 'AH'], ['R', 'AH'], ['S', 'AH'], ['SH', 'AH'], ['T', 'AH'], ['TH', 'AH'], ['V', 'AH'], ['W', 'AH'], ['Y', 'AH'], ['Z', 'AH'], ['ZH', 'AH'], ['S', 'K', 'AH'], ['S', 'L', 'AH'], ['S', 'M', 'AH'], ['S', 'N', 'AH'], 
['S', 'P', 'AH'], ['S', 'T', 'AH'], ['S', 'AH', 'B'], ['S', 'AH', 'CH'], ['S', 'AH', 'D'], ['S', 'AH', 'F'], ['S', 'AH', 'G'], ['S', 'AH', 'JH'], ['S', 'AH', 'K'], ['S', 'AH', 
'L'], ['S', 'AH', 'M'], ['S', 'AH', 'N'], ['S', 'AH', 'NG'], ['S', 'AH', 'P'], ['S', 'AH', 'S'], ['S', 'AH', 'T'], ['S', 'AH', 'TH'], ['S', 'AH', 'V'], ['S', 'AH', 'Z']]

# %%
y2 = [['M', 'AA'], ['M', 'AE'], ['M', 'AH'], ['M', 'AO'], ['M', 'AW'], ['M', 'AY'], ['M', 'EH'], ['M', 'EY'], ['M', 'IH'], ['M', 'IY'], ['M', 'OW'], ['M', 'UH'], ['M', 'UW'], ['ER'], ['B', 'ER'], ['CH', 'ER'], ['D', 'ER'], ['DH', 'ER'], ['F', 'ER'], ['HH', 'ER'], ['JH', 'ER'], ['K', 'ER'], ['L', 'ER'], ['M', 'ER'], ['N', 'ER'], ['P', 'ER'], ['SH', 'ER'], 
['T', 'ER'], ['TH', 'ER'], ['V', 'ER'], ['W', 'ER'], ['Y', 'ER'], ['Z', 'ER'], ['ZH', 'ER'], ['S', 'M', 'ER'], ['M', 'ER', 'CH'], ['M', 'ER', 'D'], ['M', 'ER', 'F'], ['M', 'ER', 'JH'], ['M', 'ER', 'K'], ['M', 'ER', 'L'], ['M', 'ER', 'N'], ['M', 'ER', 'R'], ['M', 'ER', 'S'], ['M', 'ER', 'SH'], ['M', 'ER', 'T'], ['M', 'ER', 'TH'], ['M', 'ER', 'V'], ['M', 'ER', 'Z']]

# %%
allc = []
allc.append(y1)
allc.append(y2)
allc
# Out:
# [[['S', 'AE'],
#   ['CH', 'AH'],
#   ['DH', 'AH'],
#   ['F', 'AH'],
#   ['G', 'AH'],
#   ['JH', 'AH'],
#   ['K', 'AH'],
#   ['L', 'AH'],
#   ['M', 'AH'],
#   ['N', 'AH'],
#   ['P', 'AH'],
#   ['R', 'AH'],
#   ['S', 'AH'],
#   ['SH', 'AH'],
#   ['T', 'AH'],
#   ['TH', 'AH'],
#   ['V', 'AH'],
#   ['W', 'AH'],
#   ['Y', 'AH'],
#   ['Z', 'AH'],
#   ['ZH', 'AH'],
#   ['S', 'K', 'AH'],
#   ['S', 'L', 'AH'],
#   ['S', 'M', 'AH'],
#   ['S', 'N', 'AH'],
#   ['S', 'P', 'AH'],
#   ['S', 'T', 'AH'],
#   ['S', 'AH', 'B'],
#   ['S', 'AH', 'CH'],
#   ['S', 'AH', 'D'],
#   ['S', 'AH', 'F'],
#   ['S', 'AH', 'G'],
#   ['S', 'AH', 'JH'],
#   ['S', 'AH', 'K'],
#   ['S', 'AH', 'L'],
#   ['S', 'AH', 'M'],
#   ['S', 'AH', 'N'],
#   ['S', 'AH', 'NG'],
#   ['S', 'AH', 'P'],
#   ['S', 'AH', 'S'],
#   ['S', 'AH', 'T'],
#   ['S', 'AH', 'TH'],
#   ['S', 'AH', 'V'],
#   ['S', 'AH', 'Z']],
#  [['M', 'AA'],
#   ['M', 'AE'],
#   ['M', 'AH'],
#   ['M', 'AO'],
#   ['M', 'AW'],
#   ['M', 'AY'],
#   ['M', 'EH'],
# ...

# %%
y_c = list(itertools.product(*allc))

# %%
y_c
# Out:
# [(['S', 'AE'], ['M', 'AA']),
#  (['S', 'AE'], ['M', 'AE']),
#  (['S', 'AE'], ['M', 'AH']),
#  (['S', 'AE'], ['M', 'AO']),
#  (['S', 'AE'], ['M', 'AW']),
#  (['S', 'AE'], ['M', 'AY']),
#  (['S', 'AE'], ['M', 'EH']),
#  (['S', 'AE'], ['M', 'EY']),
#  (['S', 'AE'], ['M', 'IH']),
#  (['S', 'AE'], ['M', 'IY']),
#  (['S', 'AE'], ['M', 'OW']),
#  (['S', 'AE'], ['M', 'UH']),
#  (['S', 'AE'], ['M', 'UW']),
#  (['S', 'AE'], ['ER']),
#  (['S', 'AE'], ['B', 'ER']),
#  (['S', 'AE'], ['CH', 'ER']),
#  (['S', 'AE'], ['D', 'ER']),
#  (['S', 'AE'], ['DH', 'ER']),
#  (['S', 'AE'], ['F', 'ER']),
#  (['S', 'AE'], ['HH', 'ER']),
#  (['S', 'AE'], ['JH', 'ER']),
#  (['S', 'AE'], ['K', 'ER']),
#  (['S', 'AE'], ['L', 'ER']),
#  (['S', 'AE'], ['M', 'ER']),
#  (['S', 'AE'], ['N', 'ER']),
#  (['S', 'AE'], ['P', 'ER']),
#  (['S', 'AE'], ['SH', 'ER']),
#  (['S', 'AE'], ['T', 'ER']),
#  (['S', 'AE'], ['TH', 'ER']),
#  (['S', 'AE'], ['V', 'ER']),
#  (['S', 'AE'], ['W', 'ER']),
#  (['S', 'AE'], ['Y', 'ER']),
# ...

# %%
test = [[["a", "b"], ["c", "d"], ["e", "f"]],
        [["1", "2"]], 
        [["X", "Y"], ["S"], ["S"], ["S"], ["S"], ["S"], ["S"]]
       ]

# %%
test1 = list(itertools.product(*test))
test1
# Out:
# [(['a', 'b'], ['1', '2'], ['X', 'Y']),
#  (['a', 'b'], ['1', '2'], ['S']),
#  (['a', 'b'], ['1', '2'], ['S']),
#  (['a', 'b'], ['1', '2'], ['S']),
#  (['a', 'b'], ['1', '2'], ['S']),
#  (['a', 'b'], ['1', '2'], ['S']),
#  (['a', 'b'], ['1', '2'], ['S']),
#  (['c', 'd'], ['1', '2'], ['X', 'Y']),
#  (['c', 'd'], ['1', '2'], ['S']),
#  (['c', 'd'], ['1', '2'], ['S']),
#  (['c', 'd'], ['1', '2'], ['S']),
#  (['c', 'd'], ['1', '2'], ['S']),
#  (['c', 'd'], ['1', '2'], ['S']),
#  (['c', 'd'], ['1', '2'], ['S']),
#  (['e', 'f'], ['1', '2'], ['X', 'Y']),
#  (['e', 'f'], ['1', '2'], ['S']),
#  (['e', 'f'], ['1', '2'], ['S']),
#  (['e', 'f'], ['1', '2'], ['S']),
#  (['e', 'f'], ['1', '2'], ['S']),
#  (['e', 'f'], ['1', '2'], ['S']),
#  (['e', 'f'], ['1', '2'], ['S'])]

# %%
a = ["c","d","e"]
b = ["a", "b"]
c = [[1,2],[2,3]]
c.extend((a, b))
c
# Out:
# [[1, 2], [2, 3], ['c', 'd', 'e'], ['a', 'b']]

# %%
import cmudict
consonants = [i[0] for i in cmudict.phones() if not i[1] == ['vowel']]
print(consonants)
# Out:
# ['B', 'CH', 'D', 'DH', 'F', 'G', 'HH', 'JH', 'K', 'L', 'M', 'N', 'NG', 'P', 'R', 'S', 'SH', 'T', 'TH', 'V', 'W', 'Y', 'Z', 'ZH']
