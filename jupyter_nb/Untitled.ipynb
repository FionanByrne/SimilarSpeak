# %%
import nltk
from nltk.corpus import brown
from nltk import TrigramCollocationFinder, ngrams, BigramCollocationFinder
from nltk.collocations import TrigramAssocMeasures

# %%
#trigram_measures = nltk.collocations.TrigramAssocMeasures()

# %%
test_word = ['T', 'R', "T", 'R', 'T', 'R', 'T', 'AY', 'N', 'Z']

# %%
trigrams = list(ngrams(test_word, 3))
bigrams = list(ngrams(test_word, 2))
trigrams
# Out:
# [('T', 'R', 'T'),
#  ('R', 'T', 'R'),
#  ('T', 'R', 'T'),
#  ('R', 'T', 'R'),
#  ('T', 'R', 'T'),
#  ('R', 'T', 'AY'),
#  ('T', 'AY', 'N'),
#  ('AY', 'N', 'Z')]

# %%
finder = TrigramCollocationFinder.from_words(test_word)
bi_finder = BigramCollocationFinder.from_words(test_word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-09ed0acb8910> in <module>
#       1 finder = TrigramCollocationFinder.from_words(test_word)
#       2 bi_finder = BigramCollocationFinder.from_words(test_word)
# ----> 3 list(bi_finder)
#
# TypeError: 'BigramCollocationFinder' object is not iterable

# %%
dic1 = dict(sorted(finder.ngram_fd.items(), key=lambda t: (-t[1], t[0])))
dic2 = dict(sorted(bi_finder.ngram_fd.items(), key=lambda t: (-t[1], t[0])))

# %%
t= dic1
y= dic2
for k in dic1:
    print(k, dic1[k])
# Out:
# ('T', 'R', 'T') 3
# ('R', 'T', 'R') 2
# ('AY', 'N', 'Z') 1
# ('R', 'T', 'AY') 1
# ('T', 'AY', 'N') 1

# %%
for a, b, in dic1:
    print(a,b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-3f6cfecad8ee> in <module>
# ----> 1 for a, b, in dic1:
#       2     print(a,b)
#
# ValueError: too many values to unpack (expected 2)

# %%
dic2
# Out:
# [('T', 'R', 'T'),
#  ('R', 'T', 'R'),
#  ('AY', 'N', 'Z'),
#  ('R', 'T', 'AY'),
#  ('T', 'AY', 'N')]

# %%
for a, b, in dic1:
    print(a,b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-3f6cfecad8ee> in <module>
# ----> 1 for a, b, in dic1:
#       2     print(a,b)
#
# ValueError: too many values to unpack (expected 2)

# %%
lis = set()
syll = ['<s>', 'R', "T", 'R', 'T', 'R', 'T', 'AY', 'N', '</s>']
syll2 = ["</s>", "</s>"]
syll3 = ["</s>", "K", "AH", 'T', "</s>"]
sylls = [syll] + [syll2] + [syll3]
sylls
# Out:
# [['<s>', 'R', 'T', 'R', 'T', 'R', 'T', 'AY', 'N', '</s>'],
#  ['</s>', '</s>'],
#  ['</s>', 'K', 'AH', 'T', '</s>']]

# %%
unique_sylls =  set(tuple(i) for i in sylls)
unique_sylls
# Out:
# {('</s>', '</s>'),
#  ('</s>', 'K', 'AH', 'T', '</s>'),
#  ('<s>', 'R', 'T', 'R', 'T', 'R', 'T', 'AY', 'N', '</s>')}

# %%
x = [i for syll in unique_sylls for i in syll]
x
# Out:
# ['<s>',
#  'R',
#  'T',
#  'R',
#  'T',
#  'R',
#  'T',
#  'AY',
#  'N',
#  '</s>',
#  '</s>',
#  'K',
#  'AH',
#  'T',
#  '</s>',
#  '</s>',
#  '</s>']

# %%
import cmudict
consonants = [i[0] for i in cmudict.phones() if not i[1] == ['vowel']]
test = [p for p in itertools.product(consonants, repeat=2)]
test
# Out:
# [('B', 'B'),
#  ('B', 'CH'),
#  ('B', 'D'),
#  ('B', 'DH'),
#  ('B', 'F'),
#  ('B', 'G'),
#  ('B', 'HH'),
#  ('B', 'JH'),
#  ('B', 'K'),
#  ('B', 'L'),
#  ('B', 'M'),
#  ('B', 'N'),
#  ('B', 'NG'),
#  ('B', 'P'),
#  ('B', 'R'),
#  ('B', 'S'),
#  ('B', 'SH'),
#  ('B', 'T'),
#  ('B', 'TH'),
#  ('B', 'V'),
#  ('B', 'W'),
#  ('B', 'Y'),
#  ('B', 'Z'),
#  ('B', 'ZH'),
#  ('CH', 'B'),
#  ('CH', 'CH'),
#  ('CH', 'D'),
#  ('CH', 'DH'),
#  ('CH', 'F'),
#  ('CH', 'G'),
#  ('CH', 'HH'),
#  ('CH', 'JH'),
#  ('CH', 'K'),
#  ('CH', 'L'),
#  ('CH', 'M'),
#  ('CH', 'N'),
#  ('CH', 'NG'),
#  ('CH', 'P'),
#  ('CH', 'R'),
#  ('CH', 'S'),
#  ('CH', 'SH'),
#  ('CH', 'T'),
#  ('CH', 'TH'),
#  ('CH', 'V'),
#  ('CH', 'W'),
#  ('CH', 'Y'),
#  ('CH', 'Z'),
#  ('CH', 'ZH'),
#  ('D', 'B'),
#  ('D', 'CH'),
#  ('D', 'D'),
#  ('D', 'DH'),
#  ('D', 'F'),
#  ('D', 'G'),
#  ('D', 'HH'),
#  ('D', 'JH'),
#  ('D', 'K'),
#  ('D', 'L'),
#  ('D', 'M'),
#  ('D', 'N'),
#  ('D', 'NG'),
#  ('D', 'P'),
#  ('D', 'R'),
#  ('D', 'S'),
#  ('D', 'SH'),
#  ('D', 'T'),
#  ('D', 'TH'),
#  ('D', 'V'),
#  ('D', 'W'),
#  ('D', 'Y'),
#  ('D', 'Z'),
#  ('D', 'ZH'),
#  ('DH', 'B'),
#  ('DH', 'CH'),
#  ('DH', 'D'),
#  ('DH', 'DH'),
#  ('DH', 'F'),
#  ('DH', 'G'),
#  ('DH', 'HH'),
#  ('DH', 'JH'),
#  ('DH', 'K'),
#  ('DH', 'L'),
#  ('DH', 'M'),
#  ('DH', 'N'),
#  ('DH', 'NG'),
#  ('DH', 'P'),
#  ('DH', 'R'),
#  ('DH', 'S'),
#  ('DH', 'SH'),
#  ('DH', 'T'),
#  ('DH', 'TH'),
#  ('DH', 'V'),
#  ('DH', 'W'),
#  ('DH', 'Y'),
#  ('DH', 'Z'),
#  ('DH', 'ZH'),
#  ('F', 'B'),
#  ('F', 'CH'),
#  ('F', 'D'),
#  ('F', 'DH'),
#  ('F', 'F'),
#  ('F', 'G'),
#  ('F', 'HH'),
#  ('F', 'JH'),
#  ('F', 'K'),
#  ('F', 'L'),
#  ('F', 'M'),
#  ('F', 'N'),
#  ('F', 'NG'),
#  ('F', 'P'),
#  ('F', 'R'),
#  ('F', 'S'),
#  ('F', 'SH'),
#  ('F', 'T'),
#  ('F', 'TH'),
#  ('F', 'V'),
#  ('F', 'W'),
#  ('F', 'Y'),
#  ('F', 'Z'),
#  ('F', 'ZH'),
#  ('G', 'B'),
#  ('G', 'CH'),
#  ('G', 'D'),
#  ('G', 'DH'),
#  ('G', 'F'),
#  ('G', 'G'),
#  ('G', 'HH'),
#  ('G', 'JH'),
#  ('G', 'K'),
#  ('G', 'L'),
#  ('G', 'M'),
#  ('G', 'N'),
#  ('G', 'NG'),
#  ('G', 'P'),
#  ('G', 'R'),
#  ('G', 'S'),
#  ('G', 'SH'),
#  ('G', 'T'),
#  ('G', 'TH'),
#  ('G', 'V'),
#  ('G', 'W'),
#  ('G', 'Y'),
#  ('G', 'Z'),
#  ('G', 'ZH'),
#  ('HH', 'B'),
#  ('HH', 'CH'),
#  ('HH', 'D'),
#  ('HH', 'DH'),
#  ('HH', 'F'),
#  ('HH', 'G'),
#  ('HH', 'HH'),
#  ('HH', 'JH'),
#  ('HH', 'K'),
#  ('HH', 'L'),
#  ('HH', 'M'),
#  ('HH', 'N'),
#  ('HH', 'NG'),
#  ('HH', 'P'),
#  ('HH', 'R'),
#  ('HH', 'S'),
#  ('HH', 'SH'),
#  ('HH', 'T'),
#  ('HH', 'TH'),
#  ('HH', 'V'),
#  ('HH', 'W'),
#  ('HH', 'Y'),
#  ('HH', 'Z'),
#  ('HH', 'ZH'),
#  ('JH', 'B'),
#  ('JH', 'CH'),
#  ('JH', 'D'),
#  ('JH', 'DH'),
#  ('JH', 'F'),
#  ('JH', 'G'),
#  ('JH', 'HH'),
#  ('JH', 'JH'),
#  ('JH', 'K'),
#  ('JH', 'L'),
#  ('JH', 'M'),
#  ('JH', 'N'),
#  ('JH', 'NG'),
#  ('JH', 'P'),
#  ('JH', 'R'),
#  ('JH', 'S'),
#  ('JH', 'SH'),
#  ('JH', 'T'),
#  ('JH', 'TH'),
#  ('JH', 'V'),
#  ('JH', 'W'),
#  ('JH', 'Y'),
#  ('JH', 'Z'),
#  ('JH', 'ZH'),
#  ('K', 'B'),
#  ('K', 'CH'),
#  ('K', 'D'),
#  ('K', 'DH'),
#  ('K', 'F'),
#  ('K', 'G'),
#  ('K', 'HH'),
#  ('K', 'JH'),
#  ('K', 'K'),
#  ('K', 'L'),
#  ('K', 'M'),
#  ('K', 'N'),
#  ('K', 'NG'),
#  ('K', 'P'),
#  ('K', 'R'),
#  ('K', 'S'),
#  ('K', 'SH'),
#  ('K', 'T'),
#  ('K', 'TH'),
#  ('K', 'V'),
#  ('K', 'W'),
#  ('K', 'Y'),
#  ('K', 'Z'),
#  ('K', 'ZH'),
#  ('L', 'B'),
#  ('L', 'CH'),
#  ('L', 'D'),
#  ('L', 'DH'),
#  ('L', 'F'),
#  ('L', 'G'),
#  ('L', 'HH'),
#  ('L', 'JH'),
#  ('L', 'K'),
#  ('L', 'L'),
#  ('L', 'M'),
#  ('L', 'N'),
#  ('L', 'NG'),
#  ('L', 'P'),
#  ('L', 'R'),
#  ('L', 'S'),
#  ('L', 'SH'),
#  ('L', 'T'),
#  ('L', 'TH'),
#  ('L', 'V'),
#  ('L', 'W'),
#  ('L', 'Y'),
#  ('L', 'Z'),
#  ('L', 'ZH'),
#  ('M', 'B'),
#  ('M', 'CH'),
#  ('M', 'D'),
#  ('M', 'DH'),
#  ('M', 'F'),
#  ('M', 'G'),
#  ('M', 'HH'),
#  ('M', 'JH'),
#  ('M', 'K'),
#  ('M', 'L'),
#  ('M', 'M'),
#  ('M', 'N'),
#  ('M', 'NG'),
#  ('M', 'P'),
#  ('M', 'R'),
#  ('M', 'S'),
#  ('M', 'SH'),
#  ('M', 'T'),
#  ('M', 'TH'),
#  ('M', 'V'),
#  ('M', 'W'),
#  ('M', 'Y'),
#  ('M', 'Z'),
#  ('M', 'ZH'),
#  ('N', 'B'),
#  ('N', 'CH'),
#  ('N', 'D'),
#  ('N', 'DH'),
#  ('N', 'F'),
#  ('N', 'G'),
#  ('N', 'HH'),
#  ('N', 'JH'),
#  ('N', 'K'),
#  ('N', 'L'),
#  ('N', 'M'),
#  ('N', 'N'),
#  ('N', 'NG'),
#  ('N', 'P'),
#  ('N', 'R'),
#  ('N', 'S'),
#  ('N', 'SH'),
#  ('N', 'T'),
#  ('N', 'TH'),
#  ('N', 'V'),
#  ('N', 'W'),
#  ('N', 'Y'),
#  ('N', 'Z'),
#  ('N', 'ZH'),
#  ('NG', 'B'),
#  ('NG', 'CH'),
#  ('NG', 'D'),
#  ('NG', 'DH'),
#  ('NG', 'F'),
#  ('NG', 'G'),
#  ('NG', 'HH'),
#  ('NG', 'JH'),
#  ('NG', 'K'),
#  ('NG', 'L'),
#  ('NG', 'M'),
#  ('NG', 'N'),
#  ('NG', 'NG'),
#  ('NG', 'P'),
#  ('NG', 'R'),
#  ('NG', 'S'),
#  ('NG', 'SH'),
#  ('NG', 'T'),
#  ('NG', 'TH'),
#  ('NG', 'V'),
#  ('NG', 'W'),
#  ('NG', 'Y'),
#  ('NG', 'Z'),
#  ('NG', 'ZH'),
#  ('P', 'B'),
#  ('P', 'CH'),
#  ('P', 'D'),
#  ('P', 'DH'),
#  ('P', 'F'),
#  ('P', 'G'),
#  ('P', 'HH'),
#  ('P', 'JH'),
#  ('P', 'K'),
#  ('P', 'L'),
#  ('P', 'M'),
#  ('P', 'N'),
#  ('P', 'NG'),
#  ('P', 'P'),
#  ('P', 'R'),
#  ('P', 'S'),
#  ('P', 'SH'),
#  ('P', 'T'),
#  ('P', 'TH'),
#  ('P', 'V'),
#  ('P', 'W'),
#  ('P', 'Y'),
#  ('P', 'Z'),
#  ('P', 'ZH'),
#  ('R', 'B'),
#  ('R', 'CH'),
#  ('R', 'D'),
#  ('R', 'DH'),
#  ('R', 'F'),
#  ('R', 'G'),
#  ('R', 'HH'),
#  ('R', 'JH'),
#  ('R', 'K'),
#  ('R', 'L'),
#  ('R', 'M'),
#  ('R', 'N'),
#  ('R', 'NG'),
#  ('R', 'P'),
#  ('R', 'R'),
#  ('R', 'S'),
#  ('R', 'SH'),
#  ('R', 'T'),
#  ('R', 'TH'),
#  ('R', 'V'),
#  ('R', 'W'),
#  ('R', 'Y'),
#  ('R', 'Z'),
#  ('R', 'ZH'),
#  ('S', 'B'),
#  ('S', 'CH'),
#  ('S', 'D'),
#  ('S', 'DH'),
#  ('S', 'F'),
#  ('S', 'G'),
#  ('S', 'HH'),
#  ('S', 'JH'),
#  ('S', 'K'),
#  ('S', 'L'),
#  ('S', 'M'),
#  ('S', 'N'),
#  ('S', 'NG'),
#  ('S', 'P'),
#  ('S', 'R'),
#  ('S', 'S'),
#  ('S', 'SH'),
#  ('S', 'T'),
#  ('S', 'TH'),
#  ('S', 'V'),
#  ('S', 'W'),
#  ('S', 'Y'),
#  ('S', 'Z'),
#  ('S', 'ZH'),
#  ('SH', 'B'),
#  ('SH', 'CH'),
#  ('SH', 'D'),
#  ('SH', 'DH'),
#  ('SH', 'F'),
#  ('SH', 'G'),
#  ('SH', 'HH'),
#  ('SH', 'JH'),
#  ('SH', 'K'),
#  ('SH', 'L'),
#  ('SH', 'M'),
#  ('SH', 'N'),
#  ('SH', 'NG'),
#  ('SH', 'P'),
#  ('SH', 'R'),
#  ('SH', 'S'),
#  ('SH', 'SH'),
#  ('SH', 'T'),
#  ('SH', 'TH'),
#  ('SH', 'V'),
#  ('SH', 'W'),
#  ('SH', 'Y'),
#  ('SH', 'Z'),
#  ('SH', 'ZH'),
#  ('T', 'B'),
#  ('T', 'CH'),
#  ('T', 'D'),
#  ('T', 'DH'),
#  ('T', 'F'),
#  ('T', 'G'),
#  ('T', 'HH'),
#  ('T', 'JH'),
#  ('T', 'K'),
#  ('T', 'L'),
#  ('T', 'M'),
#  ('T', 'N'),
#  ('T', 'NG'),
#  ('T', 'P'),
#  ('T', 'R'),
#  ('T', 'S'),
#  ('T', 'SH'),
#  ('T', 'T'),
#  ('T', 'TH'),
#  ('T', 'V'),
#  ('T', 'W'),
#  ('T', 'Y'),
#  ('T', 'Z'),
#  ('T', 'ZH'),
#  ('TH', 'B'),
#  ('TH', 'CH'),
#  ('TH', 'D'),
#  ('TH', 'DH'),
#  ('TH', 'F'),
#  ('TH', 'G'),
#  ('TH', 'HH'),
#  ('TH', 'JH'),
#  ('TH', 'K'),
#  ('TH', 'L'),
#  ('TH', 'M'),
#  ('TH', 'N'),
#  ('TH', 'NG'),
#  ('TH', 'P'),
#  ('TH', 'R'),
#  ('TH', 'S'),
#  ('TH', 'SH'),
#  ('TH', 'T'),
#  ('TH', 'TH'),
#  ('TH', 'V'),
#  ('TH', 'W'),
#  ('TH', 'Y'),
#  ('TH', 'Z'),
#  ('TH', 'ZH'),
#  ('V', 'B'),
#  ('V', 'CH'),
#  ('V', 'D'),
#  ('V', 'DH'),
#  ('V', 'F'),
#  ('V', 'G'),
#  ('V', 'HH'),
#  ('V', 'JH'),
#  ('V', 'K'),
#  ('V', 'L'),
#  ('V', 'M'),
#  ('V', 'N'),
#  ('V', 'NG'),
#  ('V', 'P'),
#  ('V', 'R'),
#  ('V', 'S'),
#  ('V', 'SH'),
#  ('V', 'T'),
#  ('V', 'TH'),
#  ('V', 'V'),
#  ('V', 'W'),
#  ('V', 'Y'),
#  ('V', 'Z'),
#  ('V', 'ZH'),
#  ('W', 'B'),
#  ('W', 'CH'),
#  ('W', 'D'),
#  ('W', 'DH'),
#  ('W', 'F'),
#  ('W', 'G'),
#  ('W', 'HH'),
#  ('W', 'JH'),
#  ('W', 'K'),
#  ('W', 'L'),
#  ('W', 'M'),
#  ('W', 'N'),
#  ('W', 'NG'),
#  ('W', 'P'),
#  ('W', 'R'),
#  ('W', 'S'),
#  ('W', 'SH'),
#  ('W', 'T'),
#  ('W', 'TH'),
#  ('W', 'V'),
#  ('W', 'W'),
#  ('W', 'Y'),
#  ('W', 'Z'),
#  ('W', 'ZH'),
#  ('Y', 'B'),
#  ('Y', 'CH'),
#  ('Y', 'D'),
#  ('Y', 'DH'),
#  ('Y', 'F'),
#  ('Y', 'G'),
#  ('Y', 'HH'),
#  ('Y', 'JH'),
#  ('Y', 'K'),
#  ('Y', 'L'),
#  ('Y', 'M'),
#  ('Y', 'N'),
#  ('Y', 'NG'),
#  ('Y', 'P'),
#  ('Y', 'R'),
#  ('Y', 'S'),
#  ('Y', 'SH'),
#  ('Y', 'T'),
#  ('Y', 'TH'),
#  ('Y', 'V'),
#  ('Y', 'W'),
#  ('Y', 'Y'),
#  ('Y', 'Z'),
#  ('Y', 'ZH'),
#  ('Z', 'B'),
#  ('Z', 'CH'),
#  ('Z', 'D'),
#  ('Z', 'DH'),
#  ('Z', 'F'),
#  ('Z', 'G'),
#  ('Z', 'HH'),
#  ('Z', 'JH'),
#  ('Z', 'K'),
#  ('Z', 'L'),
#  ('Z', 'M'),
#  ('Z', 'N'),
#  ('Z', 'NG'),
#  ('Z', 'P'),
#  ('Z', 'R'),
#  ('Z', 'S'),
#  ('Z', 'SH'),
#  ('Z', 'T'),
#  ('Z', 'TH'),
#  ('Z', 'V'),
#  ('Z', 'W'),
#  ('Z', 'Y'),
#  ('Z', 'Z'),
#  ('Z', 'ZH'),
#  ('ZH', 'B'),
#  ('ZH', 'CH'),
#  ('ZH', 'D'),
#  ('ZH', 'DH'),
#  ('ZH', 'F'),
#  ('ZH', 'G'),
#  ('ZH', 'HH'),
#  ('ZH', 'JH'),
#  ('ZH', 'K'),
#  ('ZH', 'L'),
#  ('ZH', 'M'),
#  ('ZH', 'N'),
#  ('ZH', 'NG'),
#  ('ZH', 'P'),
#  ('ZH', 'R'),
#  ('ZH', 'S'),
#  ('ZH', 'SH'),
#  ('ZH', 'T'),
#  ('ZH', 'TH'),
#  ('ZH', 'V'),
#  ('ZH', 'W'),
#  ('ZH', 'Y'),
#  ('ZH', 'Z'),
#  ('ZH', 'ZH')]
